# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../../data/static/plot.png')
imgplot = plt.imshow(img)
plt.show()

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# /home/user/Documents/Fourth_year/SciComp/miniProject2/miniproj/HZZ_app/notebooks
